# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...

# %%
# !python3 main.py --api_key <YOUR_API_KEY> --camera_uuid <YOUR_CAMERA_UUID> --name <YOUR_REQUESTED_NAME> --

# %%
import cv2

# %%
stream_url = 'https://console.rhombussystems.com/share/live/gwUBNcnvR26r0KRn3mPC3A/'

# %%
cap = cv2.VideoCapture(stream_url,cv2.CAP_FFMPEG)

# %%
cap.isOpened()
# Out:
# False

# %%
https://console.rhombussystems.com/share/live/gwUBNcnvR26r0KRn3mPC3A/

# %%
request.url_root
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 request.url_root
#
# NameError: name 'request' is not defined
